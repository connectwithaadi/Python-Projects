# %% [markdown]
# # TO DO List

# %%
tasks = []

def add_task():
  task = input("Enter the task: ")

  tasks.append({
      "task": task,
      "completed": False
  })

  print("task added ")

def view_tasks():
  if not tasks:
    print("No Tasks are available")
    return

  print("\nYour Tasks\n")

  for i, task in enumerate(tasks, start=1):
    status = "Done" if task["completed"] else "Pending"

    print(f"{i}. {task['task']} [{status}]")

def complete_task():

  view_tasks()

  if not tasks:
    return

  number = int(input("Task number: "))

  if 1 <= number <= len(tasks):
    tasks[number - 1]["completed"] = True
    print("Task completed")
  else:
    print("Invalid task number")


def delete_task():

  view_tasks()

  if not tasks:
    return

  number = int(input("Task number: "))

  if 1 <= number <= len(tasks):
    tasks.pop(number - 1)
    print("Task deleted")
  else:
    print("invalid task number")

while True:

    print("\nTo-Do List")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Complete Task")
    print("4. Delete Task")
    print("5. Exit")

    choice = input("Choice: ")

    if choice == "1":
        add_task()

    elif choice == "2":
        view_tasks()

    elif choice == "3":
        complete_task()

    elif choice == "4":
        delete_task()

    elif choice == "5":
        print("Goodbye!")
        break

    else:
        print("Invalid Choice")
# Out:
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter the task: subha uth gya
# task added
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter the task: muh dho liya
# task added
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter the task: khana kha liya
# task added
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 1
# Enter the task: nach liya
# task added
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 2
#
# Your Tasks
#
# 1. subha uth gya [Pending]
# 2. muh dho liya [Pending]
# 3. khana kha liya [Pending]
# 4. nach liya [Pending]
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. subha uth gya [Pending]
# 2. muh dho liya [Pending]
# 3. khana kha liya [Pending]
# 4. nach liya [Pending]
# Task number: 1
# Task completed
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. subha uth gya [Done]
# 2. muh dho liya [Pending]
# 3. khana kha liya [Pending]
# 4. nach liya [Pending]
# Task number: 2
# Task completed
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. subha uth gya [Done]
# 2. muh dho liya [Done]
# 3. khana kha liya [Pending]
# 4. nach liya [Pending]
# Task number: 3
# Task completed
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 4
#
# Your Tasks
#
# 1. subha uth gya [Done]
# 2. muh dho liya [Done]
# 3. khana kha liya [Done]
# 4. nach liya [Pending]
# Task number: 4
# Task deleted
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 3
#
# Your Tasks
#
# 1. subha uth gya [Done]
# 2. muh dho liya [Done]
# 3. khana kha liya [Done]
# Task number: 5
# Invalid task number
#
# To-Do List
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. Delete Task
# 5. Exit
# Choice: 5
# Goodbye!
