# %% [markdown]
# # Calculator

# %%
from binascii import b2a_base64
def add(a,b):
  return a+b

def subtract(a, b):
  return a - b

def multiply(a,b):
  return a * b

def divide(a,b):
  if b==0:
    return "Zero se divide rules ke khilaf hai"
  return a/b

def modulus(a,b):
  return a%b

def power(a,b):
  return a**b

def floor_division(a,b):
  if b==0:
    return "Zero se divide krna rules ke khilaf hai"
  return a//b

def display_menu():
  print("\n====Calculator====")
  print("1. Addition")
  print("2. Subtraction")
  print("3. Multiplication")
  print("4. Division")
  print("5. Modulus")
  print("6. Power")
  print("7. Floor Division")
  print("8. Exit")

while True:
  display_menu()

  choice = input("Enter tumhari choice: ")

  if choice == "8":
    print("Tumhara kaam ho gya na, Thank you bolo")
    break

  if choice not in ["1","2","3","4","5","6","7"]:
    print("Tumhne kuch to galat choice kr liya hai")
    continue

  num1 = float(input("Enter the pehela number: "))
  num2 = float(input("Enter the dusra nubmer:  "))

  if choice == "1":
    print("Result:", add(num1, num2))

  elif choice == "2":
    print("Result:", subtract(num1, num2))

  elif choice == "3":
    print("Result:", multiply(num1, num2))

  elif choice == "4":
    print("Result:", divide(num1, num2))

  elif choice == "5":
    print("Result:", modulus(num1, num2))

  elif choice == "6":
    print("Result:", power(num1, num2))

  elif choice == "7":
    print("Result:", floor_division(num1, num2))
# Out:
# ====Calculator====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Floor Division
# 8. Exit
# Enter tumhari choice: 1
# Enter the pehela number: 3
# Enter the dusra nubmer:  6
# Result: 9.0
#
# ====Calculator====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Floor Division
# 8. Exit
# Enter tumhari choice: 2
# Enter the pehela number: 8
# Enter the dusra nubmer:  9
# Result: -1.0
#
# ====Calculator====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Floor Division
# 8. Exit
# Enter tumhari choice: 3
# Enter the pehela number: 4
# Enter the dusra nubmer:  6
# Result: 24.0
#
# ====Calculator====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Floor Division
# 8. Exit
# Enter tumhari choice: 4
# Enter the pehela number: 2
# Enter the dusra nubmer:  0
# Result: Zero se divide rules ke khilaf hai
#
# ...
