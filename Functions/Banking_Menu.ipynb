# %% [markdown]
# # Banking Menu

# %%
balance = 0.0

def deposit():
  global balance

  amount = float(input("Enter the Deposite Amount: "))

  if amount > 0:
    balance = balance + amount
    print(f"{amount: .2f} deposited successfully ")
  else:
    print("Invalid amount. ")

def withdraw():
  global balance

  amount = float(input("Enter the withdrawal amount: "))

  if amount <= 0:
    print("Invalid amount.")

  else:
    balance = balance - amount
    print(f"{amount:.2f} withdrawn successfully")


def check_blance():
  print(f"Current balance: {balance:.2f}")

def display_menu():
  print("\n====Banking Menu====")
  print("1. Deposit")
  print("2. Withdraw")
  print("3. Check Balance")
  print("4. Exit")

while True:

  display_menu()

  choice = input("Enter your choice: ")

  if choice == "1":
    deposit()

  elif choice == "2":
    withdraw()

  elif choice == "3":
    check_blance()

  elif choice == "4":
    print("Humare bank ki sewa leke ke liye sukriya")
    break

  else:
    print("Enter the valid choice. ")
# Out:
# ====Banking Menu====
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 1
# Enter the Deposite Amount: 89000
#  89000.00 deposited successfully
#
# ====Banking Menu====
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 1
# Enter the Deposite Amount: 10000
#  10000.00 deposited successfully
#
# ====Banking Menu====
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 2
# Enter the withdrawal amount: 50000
# 50000.00 withdrawn successfully
#
# ====Banking Menu====
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 3
# Current balance: 49000.00
#
# ====Banking Menu====
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 4
# Humare bank ki sewa leke ke liye sukriya
