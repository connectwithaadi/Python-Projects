# %% [markdown]
# # Student Result Analyzer

# %%
from functools import reduce

print("=" * 60)
print("Student Result Analyzer")
print("=" * 60)

students = [
    {"name": "Aadu", "marks": 92},
    {"name": "Aditya", "marks": 75},
    {"name": "Aryan", "marks": 88},
    {"name": "Vicky", "marks": 63},
    {"name": "Sourabh", "marks": 48},
    {"name": "SHikhar", "marks": 95},
]

print("\nOriginal Data")
for student in students:
  print(student)

# ------------------------------------------------
# List Comprehension
# ------------------------------------------------
student_names = [student["name"] for student in students]

print("\nStudent Names")
print(student_names)

# ------------------------------------------------
# Dictionary Comprehension
# ------------------------------------------------

student_marks = {
    student["name"]: student["marks"]
    for student in students
}

print("\nDictionary")
print(student_marks)

# ------------------------------------------------
# map()
# ------------------------------------------------

bonus_marks = list(
    map(
        lambda student: {
            "name": student["name"],
            "marks": student["marks"] + 5
        },
        students
    )
)

print("\nBonus Marks")
print(bonus_marks)

# ------------------------------------------------
# filter()
# ------------------------------------------------

passed_students = list(
    filter(
        lambda student: student["marks"] >= 50,
        students
    )
)

print("\nPassed Students")
for student in passed_students:
    print(student)

# ------------------------------------------------
# reduce()
# ------------------------------------------------

total_marks = reduce(
    lambda total, student: total + student["marks"],
    students,
    0
)

average = total_marks / len(students)

print("\nTotal Marks :", total_marks)
print("Average :", round(average, 2))

# ------------------------------------------------
# sorted()
# ------------------------------------------------

ranking = sorted(
    students,
    key=lambda student: student["marks"],
    reverse=True
)

print("\nRanking")

for i, student in enumerate(ranking, start=1):
    print(i, student["name"], student["marks"])

# ------------------------------------------------
# Lambda
# ------------------------------------------------

grade = lambda marks: (
    "A"
    if marks >= 90
    else "B"
    if marks >= 75
    else "C"
    if marks >= 60
    else "Fail"
)

print("\nGrades")

for student in students:
    print(student["name"], ":", grade(student["marks"]))
# Out:
# ============================================================
# Student Result Analyzer
# ============================================================
#
# Original Data
# {'name': 'Aadu', 'marks': 92}
# {'name': 'Aditya', 'marks': 75}
# {'name': 'Aryan', 'marks': 88}
# {'name': 'Vicky', 'marks': 63}
# {'name': 'Sourabh', 'marks': 48}
# {'name': 'SHikhar', 'marks': 95}
#
# Student Names
# ['Aadu', 'Aditya', 'Aryan', 'Vicky', 'Sourabh', 'SHikhar']
#
# Dictionary
# {'Aadu': 92, 'Aditya': 75, 'Aryan': 88, 'Vicky': 63, 'Sourabh': 48, 'SHikhar': 95}
#
# Bonus Marks
# [{'name': 'Aadu', 'marks': 97}, {'name': 'Aditya', 'marks': 80}, {'name': 'Aryan', 'marks': 93}, {'name': 'Vicky', 'marks': 68}, {'name': 'Sourabh', 'marks': 53}, {'name': 'SHikhar', 'marks': 100}]
#
# Passed Students
# {'name': 'Aadu', 'marks': 92}
# {'name': 'Aditya', 'marks': 75}
# {'name': 'Aryan', 'marks': 88}
# {'name': 'Vicky', 'marks': 63}
# {'name': 'SHikhar', 'marks': 95}
#
# Total Marks : 461
# Average : 76.83
#
# Ranking
# 1 SHikhar 95
# 2 Aadu 92
# 3 Aryan 88
# 4 Aditya 75
# 5 Vicky 63
# 6 Sourabh 48
#
# Grades
# Aadu : A
# Aditya : B
# Aryan : B
# Vicky : C
# Sourabh : Fail
# SHikhar : A
