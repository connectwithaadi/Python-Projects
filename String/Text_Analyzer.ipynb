# %%
text = input("Enter the sentence apart from your imagination:\n")

characters = len(text)
characters_without_spaces = len(text.replace(" ",""))

words = len(text.split())

vowels = 0
consonants = 0
digits = 0
spaces = 0
uppercase = 0
lowercase = 0

for char in text:

  if char.lower() in "aeiou":
    vowels += 1
  elif char.isalpha():
    consonants += 1
  if char.isdigit():
    digits += 1
  if char == " ":
    spaces += 1
  if char.isupper():
    uppercase +=1
  if char.islower():
    lowercase += 1

print("\nText Analysis")
print("-" * 35)

print(f"Total Characters            : {characters}")
print(f"Characters (No Spaces)      : {characters_without_spaces}")
print(f"Total Words                 : {words}")
print(f"Vowels                      : {vowels}")
print(f"Consonants                  : {consonants}")
print(f"Digits                      : {digits}")
print(f"Spaces                      : {spaces}")
print(f"Uppercase Letters           : {uppercase}")
print(f"Lowercase Letters           : {lowercase}")
# Out:
# Enter the sentence apart from your imagination:
# Hello brother, I am aadi, an AI Engineer
#
# Text Analysis
# -----------------------------------
# Total Characters            : 40
# Characters (No Spaces)      : 33
# Total Words                 : 8
# Vowels                      : 16
# Consonants                  : 15
# Digits                      : 0
# Spaces                      : 7
# Uppercase Letters           : 5
# Lowercase Letters           : 26
